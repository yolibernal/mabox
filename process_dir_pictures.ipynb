# %% [markdown]
# # Preprocessing

# %%
import requests

def lookup_address_lat_lng(address):
    res = requests.get("https://nominatim.openstreetmap.org/search", params={
        "format": "json",
        "q": address,
    })
    results = res.json()
    if len(results) == 0:
        raise Exception(f"No results found for {address}")

    result = results[0]
    bb = result["boundingbox"]

    return [(float(bb[0]) + float(bb[1])) / 2, (float(bb[2]) + float(bb[3])) / 2]

# %%
import os
import json

configs = []
errors = []
# traverse root directory, and list directories as dirs and files as files
for root, dirs, files in os.walk("/Users/jonas/Documents/Familienbilder_no_videos"):
    try:
        path = root.split(os.sep)
        if "TODO" in path:
            continue
        parts = path[5:]
        address = ""
        year = None
        for part in parts:
            if part.isdigit():
                year = part
            else:
                if address == "":
                    address = part
                else:
                    address = address + ", " + part
        if year is not None:
            print(f"Looking up {address} | {year}")
            lat_lng = lookup_address_lat_lng(address)
        else:
            continue
        for file in files:
            file_config = {
                "path": "pictures"+ "/" + "/".join(parts + [file]),
                "date": year,
                "location": {
                    "lat": lat_lng[0],
                    "lng": lat_lng[1],
                }
            }
            configs.append(file_config)
    except Exception as e:
        errors.append(e)
        print(e)

print(errors)
with open("./picture-configs-generated.json", "w") as f:
    json.dump(configs, f)
# Out:
# Looking up USA, Californien, San Francisco | 1990
# Looking up USA, Florida | 2009
# Looking up USA, Florida, Orlando | 2009
# Looking up USA, Florida, Orlando, Sea World | 2009
# Looking up USA, Florida, Orlando, Sea World | 2009
# Looking up USA, Florida, Orlando | 2009
# Looking up USA, Florida, Orlando, Universal Studio Park | 2009
# Looking up USA, Florida, Orlando, Universal Studio Park | 2009
# Looking up USA, Florida, Key West | 2009
# Looking up USA, Florida, Key West | 2009
# Looking up USA, Florida, Overseas Highway | 2009
# Looking up USA, Florida, Overseas Highway | 2009
# Looking up USA, Florida, Kissimmee | 2009
# Looking up USA, Florida, Kissimmee | 2009
# Looking up USA, Florida, Miami | 2009
# Looking up USA, Florida, Miami | 2009
# Looking up USA, Florida, Everglades | 2009
# Looking up USA, Florida, Everglades | 2009
# Looking up England, Macclesfield | 2009
# Looking up England, Macclesfield | 2010
# Looking up England, Peckforton Castle | 2010
# Looking up England, Manchester | 2010
# Looking up France, La Plagne | 2010
# Looking up France, Baerenthal, Alsace | 1988
# Looking up France, Baerenthal, Alsace | 1990
# Looking up France, Béziers | 1981
# Looking up France, Weiterswiller, Alsace | 1995
# Looking up France, Weiterswiller, Alsace | 1995
# Looking up France, Weiterswiller, Alsace | 2001
# Looking up France, Weiterswiller, Alsace | 2006
# Looking up France, Weiterswiller, Alsace | 2010
# Looking up France, Weiterswiller, Alsace | 1997
# Looking up France, Weiterswiller, Alsace | 1999
# Looking up France, Weiterswiller, Alsace | 1998
# Looking up France, Weiterswiller, Alsace | 1996
# Looking up France, Weiterswiller, Alsace | 2002
# Looking up Germany, Leopoldshafen, Donauring 3a | 1983
# Looking up Germany, Leopoldshafen, Donauring 3a | 1984
# Looking up Germany, Leopoldshafen, Donauring 3a | 1997
# Looking up Germany, Leopoldshafen, Donauring 3a | 1990
# Looking up Germany, Leopoldshafen, Donauring 3a | 1996
# Looking up Germany, Leopoldshafen, Hafenterrain 2 | 2001
# Looking up Germany, Leopoldshafen, Evangelische Kirche | 1994
# Looking up Germany, Leopoldshafen, Evangelische Kirche | 2008
# Looking up Germany, Leopoldshafen, Restaurant Da Bruno | 1996
# No results found for Germany, Leopoldshafen, Restaurant Da Bruno
# Looking up Germany, Eiffel | 2012
# Looking up Germany, Kinzigtal, Schloss Ortenberg | 2012
# No results found for Germany, Kinzigtal, Schloss Ortenberg
# Looking up Germany, Baiersbronn | 2010
# Looking up Portugal, Lissabon | 2002
# Looking up Ireland, County Clare | 1991
# Looking up Switzerland, Veysonnaz | 2008
# Looking up Switzerland, Saas Fee | 1988
# Looking up Switzerland, Les Collons | 2009
# Looking up Tunesia, Aldiana | 2004
# Looking up China, Beijing | 1990
# Looking up China, Forbidden City | 1990
# Looking up Romania | 2013
# Looking up Romania | 2012
# Looking up Romania | 2010
# Looking up Italy, Marina di Venezia, Venedig | 1995
# No results found for Italy, Marina di Venezia, Venedig
# Looking up Italy, Marina di Venezia, Venedig | 1998
# No results found for Italy, Marina di Venezia, Venedig
# Looking up Italy, Gardasee | 2014
# Looking up Italy, Gardasee | 2011
# Looking up Italy | 1995
# Looking up Italy, Livigno | 2001
# Looking up Italy, Venedig | 1999
# Looking up Austria, Serfaus | 1988
# Looking up Austria, Serfaus | 1995
# Looking up Austria, Kufstein | 1972
# Looking up Austria, Kufstein | 1973
# Looking up Austria, Tauplitz | 2003
# Looking up Austria, Fontanella | 2013
# Looking up Austria, Innsbruck | 1973
# Looking up Austria, Schattwald | 2006
# Looking up Austria, Lingenau | 1969
# Looking up Greece, Thassos | 2007
# Looking up Guadeloupe | 2020
# Looking up Canada, Niagara Falls, Ontario | 2000
# [Exception('No results found for Germany, Goethestraße 34, 76356 Weingarten'), Exception('No results found for Germany, Karlsruhe, Comenius Realschule'), Exception('No results found for Germany, Karlsruhe, Günter Klotz Anlage'), Exception('No results found for Germany, Karlsruhe, Hans-Jakob-Str'), Exception('No results found for Germany, Karlsruhe, Marienkrankenhaus'), Exception('No results found for Germany, Karlsruhe, Marienkrankenhaus'), Exception('No results found for Germany, Fahler Loch, Feldberg'), Exception('No results found for Germany, Leopoldshafen, Herrmann Übelhör Halle'), Exception('No results found for Germany, Leopoldshafen, Restaurant Da Bruno'), Exception('No results found for Germany, Kinzigtal, Schloss Ortenberg'), Exception('No results found for Italy, Marina di Venezia, Venedig'), Exception('No results found for Italy, Marina di Venezia, Venedig')]
